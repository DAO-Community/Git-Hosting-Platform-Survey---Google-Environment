# %% [markdown]
# # DAO Community Git Hosting Platform Survey Report Data Generator using Python-Polars in Google Environment
# ---
# ## Bar Diagram Generator using Polars

# %% [markdown]
# ![](https://img.shields.io/badge/Version%201.0.0-333333?style=for-the-badge)![](https://img.shields.io/badge/Made%20with-808080?style=for-the-badge)[![](https://img.shields.io/badge/Google%20Colaboratory-4d4d4d?style=for-the-badge&logo=googlecolab)](https://docs.jupyter.org/en/latest/)![](https://img.shields.io/badge/And-808080?style=for-the-badge)[![](https://img.shields.io/badge/Python%203.10.12-306998?style=for-the-badge&logo=Python&logoColor=FFD43B)](https://docs.python.org/3.10/)[![](https://img.shields.io/badge/Polars%200.17.3-FFD43B?style=for-the-badge&logo=Polars&logoColor=306998)](https://docs.python.org/3.11/)
#
# ![](https://img.shields.io/badge/Repo-808080?style=for-the-badge)[![](https://img.shields.io/badge/GitLab-554488?style=for-the-badge&logo=GitLab)](https://gitlab.com/amlc_ai_dev/amlc_ai)

# %%
from __future__ import annotations

# %% [markdown]
# # Mount Drive

# %%
from pathlib import Path

from google.colab import drive

mount_point: Path = Path("/gdrive")

drive.mount(mountpoint=str(mount_point.resolve()), force_remount=True)
# Out:
# Mounted at /gdrive

# %%
base_path: Path = (
    mount_point
    / "MyDrive"
    / "Survey"
    / "DAO Community Git Hosting Platform Survey - Google Environment"
)
base_path.mkdir(parents=False, exist_ok=True)

output_data_path: Path = base_path / "Data"
output_data_path.mkdir(parents=False, exist_ok=True)

# %%
## NOTE: import-ipynb cannot work with notebooks in Google Drive, thus the workaround below.
type_objects_module = base_path / "Generator" / "Type Objects Polars.ipynb"

if type_objects_module.exists():
    type_objects_module: str = f"{type_objects_module}"
    # %run -n "$type_objects_module"
    """Creates the ff:
        Eyears_of_experience,
        Egit_hosting_platform,
        Ecareer_level,
        Edao_pillar,
        Epast_next,
        Epast_next_all,
        TDcolumns,
        df_columns_dtypes_dict
    """
else:
    print(f"Module '{type_objects_module}' does not exist.")

# %%
import polars as pl

df: pl.dataframe.frame.DataFrame = pl.read_parquet(
    source=output_data_path / "base_data.parquet", use_pyarrow=True
)
print("head:", df.head())
print("shape:", df.shape)
# Out:
# head: shape: (5, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬──────────┬──────────┐
# │ used_git_h ┆ current_gi ┆ years_of_e ┆ past_next_ ┆ past_next_ ┆ career_lev ┆ dao_pill ┆ alias    │
# │ osting_pla ┆ t_hosting_ ┆ xperience  ┆ github     ┆ gitlab     ┆ el         ┆ ar       ┆ ---      │
# │ tform      ┆ platform   ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---      ┆ str      │
# │ ---        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        ┆ str      ┆          │
# │ str        ┆ str        ┆            ┆            ┆            ┆            ┆          ┆          │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪══════════╪══════════╡
# │ GitHub,    ┆ GitHub,    ┆ 4 to 6     ┆ Worked     ┆ Worked     ┆ 2          ┆ Data     ┆ Jeremy   │
# │ GitLab,    ┆ GitLab,    ┆ years      ┆ with in    ┆ with in    ┆            ┆ Admin    ┆          │
# │ Codeberg   ┆ Codeberg   ┆            ┆ PAST       ┆ PAST       ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆          ┆          │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆          │
# │ GitHub,    ┆ GitHub,    ┆ 2 to 4     ┆ Worked     ┆ Worked     ┆ 2          ┆ Data Eng ┆ Paul     │
# │ GitLab     ┆ GitLab     ┆ years      ┆ with in    ┆ with in    ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ PAST       ┆ PAST       ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆          ┆          │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆          │
# │ null       ┆ null       ┆ null       ┆ Want to    ┆ Want to    ┆ 2          ┆ Data     ┆ Victoria │
# │            ┆            ┆            ┆ work with  ┆ work with  ┆            ┆ Science  ┆          │
# │            ┆            ┆            ┆ in NEXT    ┆ in NEXT    ┆            ┆ & Analyt ┆          │
# │            ┆            ┆            ┆ years      ┆ years      ┆            ┆ ics      ┆          │
# │ GitLab     ┆ null       ┆ <2 years   ┆ Want to    ┆ Worked     ┆ 2          ┆ Data Eng ┆ Benjamin │
# │            ┆            ┆            ┆ work with  ┆ with in    ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ in NEXT    ┆ PAST       ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years      ┆ years,     ┆            ┆          ┆          │
# │            ┆            ┆            ┆            ┆ Want …     ┆            ┆          ┆          │
# │ GitHub     ┆ GitHub     ┆ 2 to 4     ┆ Worked     ┆ Want to    ┆ 1          ┆ Data Eng ┆ David    │
# │            ┆            ┆ years      ┆ with in    ┆ work with  ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ PAST       ┆ in NEXT    ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years,     ┆ years      ┆            ┆          ┆          │
# │            ┆            ┆            ┆ Want …     ┆            ┆            ┆          ┆          │
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴──────────┴──────────┘
# shape: (105, 8)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Bar
# **Line, bar and pie charts 27.3.1** <br>
# Chart Type: **Bar Chart (Grouped)** <br>
# See [Flourish Sankey Diagram](https://app.flourish.studio/@flourish/sankey) for requirements. <br>
# <hr>
#
# This code generates three (3) diagram json files:
# * `bar-dao_pillar-main.json`
# * `bar-years_of_experience-main.json`
# * `bar-career_level-main.json`
# <br>
#
# ### `Data` Tab
# #### Order
# | A | B | C | D |
# | --- | --- | --- | --- |
# | dao_pillar | counts | group | row_filter |
# | years_of_experience | counts | group | row_filter |
# | career_level | counts | group | row_filter | <br>
# <br>
#
# #### Configuration
# - **Labels/time: A**
# - **Values: B**
# - **Charts grid: C**
# - **Row filter: D**

# %%
from typing import Any, Mapping, Optional, TypedDict


def bar_maker(
    df: pl.dataframe.frame.DataFrame, value_counts_column_name: str, *args, **kwargs
) -> Optional[pl.DataFrame]:
    """Creates json & parquets for bar diagrams.

    Args:
        Required:
            df: target Polars dataframe
            value_counts_column_name
        Optional:
            group_column_name
            row_filter_column_name
            debug: if True, then performs a dry run, saving to file disabled
            verbose: if True, then shows process

    Returns:
        Optional:
            Given: debug
            When:  True
            Then:  Polars DataFrame

    Raises:
        None
    """

    ## Prepare Args/Kwargs
    class TDdefaultKwargs(TypedDict):
        group_column_name: str
        row_filter_column_name: str
        debug: bool
        verbose: bool

    defaultKwargs: TDdefaultKwargs = TDdefaultKwargs(
        group_column_name="All respondents",
        row_filter_column_name="All respondents",
        debug=False,
        verbose=False,
    )
    allKwargs: Mapping[Any, Any] = {**defaultKwargs, **kwargs}

    group_column_name: str = allKwargs["group_column_name"]
    row_filter_column_name: str = allKwargs["row_filter_column_name"]
    debug: bool = allKwargs["debug"]
    verbose: bool = allKwargs["verbose"]

    ## Prepare Base DataFrame
    df_out: pl.dataframe.frame.DataFrame = (
        df.get_column(value_counts_column_name)
        .value_counts()
        .with_columns(
            pl.col("counts")
            # .cast(pl.Float32)
            .apply(lambda _: _ / df.height * 100, skip_nulls=True).round(2),
            pl.col(value_counts_column_name).fill_null("None"),
        )
        .sort(by="counts", descending=True)
        .with_columns(
            group=pl.lit(group_column_name),
            row_filter=pl.lit(row_filter_column_name),
        )
    )

    ## Prepare Base Path
    path_bar: Path = output_data_path / "Bar Diagrams"
    path_bar.mkdir(parents=False, exist_ok=True)

    file_name: Path = Path(
        str(
            "bar-"
            + value_counts_column_name
            + "-"
            + group_column_name.replace(" ", "_")
            + "-"
            + row_filter_column_name.replace(" ", "_")
        )
    ).with_suffix(".parquet")

    if verbose:
        print("print(df_out)")
        exec("print(df_out)")
        print()
        print(
            """print(f\"file name: {value_counts_column_name}/parquet/{file_name}\")"""
        )
        exec(
            """print(f\"file name: {value_counts_column_name}/parquet/{file_name}\")"""
        )
        print()

    if debug:
        return df_out
    else:
        ## Prepare Base Path
        path_bar_parquet: Path = path_bar / value_counts_column_name / "parquet"
        path_bar_parquet.mkdir(parents=True, exist_ok=True)

        ## Save dataframe to json
        ## Flourish accepts Excel, CSV, TSV, JSON, GeoJSON
        df_out.write_parquet(file=path_bar_parquet / file_name, use_pyarrow=True)


## --- Debug ---
df_test: pl.DataFrame = pl.DataFrame(
    {"metasyntactic": ["foo", None, "bar", "bar", "foo", "bar"]}
)

df_validate: pl.DataFrame = pl.DataFrame(
    {
        "metasyntactic": ["bar", "foo", "None"],
        "counts": [50.0, 33.33, 16.67],
        "group": ["All respondents", "All respondents", "All respondents"],
        "row_filter": ["All respondents", "All respondents", "All respondents"],
    }
)

from polars.testing import assert_frame_equal

assert_frame_equal(
    bar_maker(
        df=df_test, value_counts_column_name="metasyntactic", debug=True, verbose=True
    ),
    df_validate,
)
# Out:
# print(df_out)
# shape: (3, 4)
# ┌───────────────┬────────┬─────────────────┬─────────────────┐
# │ metasyntactic ┆ counts ┆ group           ┆ row_filter      │
# │ ---           ┆ ---    ┆ ---             ┆ ---             │
# │ str           ┆ f64    ┆ str             ┆ str             │
# ╞═══════════════╪════════╪═════════════════╪═════════════════╡
# │ bar           ┆ 50.0   ┆ All respondents ┆ All respondents │
# │ foo           ┆ 33.33  ┆ All respondents ┆ All respondents │
# │ None          ┆ 16.67  ┆ All respondents ┆ All respondents │
# └───────────────┴────────┴─────────────────┴─────────────────┘
#
# print(f"file name: {value_counts_column_name}/parquet/{file_name}")
# file name: metasyntactic/parquet/bar-metasyntactic-All_respondents-All_respondents.parquet

# %% [markdown]
# ### Dry Run

# %%
_: Any = bar_maker(
    df=df, value_counts_column_name="dao_pillar", debug=True, verbose=True
)
_: Any = bar_maker(
    df=df, value_counts_column_name="years_of_experience", debug=True, verbose=True
)
_: Any = bar_maker(
    df=df, value_counts_column_name="career_level", debug=True, verbose=True
)
# Out:
# print(df_out)
# shape: (4, 4)
# ┌──────────────────────────┬────────┬─────────────────┬─────────────────┐
# │ dao_pillar               ┆ counts ┆ group           ┆ row_filter      │
# │ ---                      ┆ ---    ┆ ---             ┆ ---             │
# │ str                      ┆ f64    ┆ str             ┆ str             │
# ╞══════════════════════════╪════════╪═════════════════╪═════════════════╡
# │ Data Engineering         ┆ 55.24  ┆ All respondents ┆ All respondents │
# │ Data Admin               ┆ 22.86  ┆ All respondents ┆ All respondents │
# │ Data Science & Analytics ┆ 18.1   ┆ All respondents ┆ All respondents │
# │ AFC                      ┆ 3.81   ┆ All respondents ┆ All respondents │
# └──────────────────────────┴────────┴─────────────────┴─────────────────┘
#
# print(f"file name: {value_counts_column_name}/parquet/{file_name}")
# file name: dao_pillar/parquet/bar-dao_pillar-All_respondents-All_respondents.parquet
#
# print(df_out)
# shape: (5, 4)
# ┌─────────────────────┬────────┬─────────────────┬─────────────────┐
# │ years_of_experience ┆ counts ┆ group           ┆ row_filter      │
# │ ---                 ┆ ---    ┆ ---             ┆ ---             │
# │ str                 ┆ f64    ┆ str             ┆ str             │
# ╞═════════════════════╪════════╪═════════════════╪═════════════════╡
# │ <2 years            ┆ 52.38  ┆ All respondents ┆ All respondents │
# │ 2 to 4 years        ┆ 26.67  ┆ All respondents ┆ All respondents │
# │ None                ┆ 14.29  ┆ All respondents ┆ All respondents │
# │ 4 to 6 years        ┆ 5.71   ┆ All respondents ┆ All respondents │
# │ 8 to 10 years       ┆ 0.95   ┆ All respondents ┆ All respondents │
# └─────────────────────┴────────┴─────────────────┴─────────────────┘
#
# print(f"file name: {value_counts_column_name}/parquet/{file_name}")
# file name: years_of_experience/parquet/bar-years_of_experience-All_respondents-All_respondents.parquet
#
# print(df_out)
# shape: (5, 4)
# ┌──────────────┬────────┬─────────────────┬─────────────────┐
# │ career_level ┆ counts ┆ group           ┆ row_filter      │
# │ ---          ┆ ---    ┆ ---             ┆ ---             │
# │ str          ┆ f64    ┆ str             ┆ str             │
# ╞══════════════╪════════╪═════════════════╪═════════════════╡
# │ 2            ┆ 44.76  ┆ All respondents ┆ All respondents │
# │ 3            ┆ 24.76  ┆ All respondents ┆ All respondents │
# │ 1            ┆ 15.24  ┆ All respondents ┆ All respondents │
# │ 4            ┆ 7.62   ┆ All respondents ┆ All respondents │
# │ 5            ┆ 7.62   ┆ All respondents ┆ All respondents │
# └──────────────┴────────┴─────────────────┴─────────────────┘
#
# print(f"file name: {value_counts_column_name}/parquet/{file_name}")
# file name: career_level/parquet/bar-career_level-All_respondents-All_respondents.parquet

# %% [markdown]
# ### All Respondents

# %%
bar_maker(df=df, value_counts_column_name="dao_pillar")
bar_maker(df=df, value_counts_column_name="years_of_experience")
bar_maker(df=df, value_counts_column_name="career_level")

# %% [markdown]
# ### By Category
#
# `📝Note`: Wait for some process to finish writing the files, some cells might finish running but *Google Drive* might take a while to save the files.

# %%
for _ in Edao_pillar:
    df_tmp = df.filter(pl.col("dao_pillar") == _.value)
    print(df_tmp)

    ## Skip filtered empty dataframes
    if df_tmp.is_empty():
        continue

    ## Value Count Column: years_of_experience
    ## Group Column: dao_pillar
    ## Row Filter Column: career_level
    for __ in Ecareer_level:
        df_tmp_bar: pl.DataFrame = df_tmp.filter(pl.col("career_level") == __.value)
        if df_tmp_bar.is_empty():
            continue
        bar_maker(
            df=df_tmp_bar,
            value_counts_column_name="years_of_experience",
            group_column_name=_.value,
            row_filter_column_name=__.value,
        )

    ## Value Count Column: career_level
    ## Group Column: dao_pillar
    ## Row Filter Column: years_of_experience
    for __ in Eyears_of_experience:
        df_tmp_bar: pl.DataFrame = df_tmp.filter(
            pl.col("years_of_experience") == __.value
        )
        if df_tmp_bar.is_empty():
            continue
        bar_maker(
            df=df_tmp_bar,
            value_counts_column_name="career_level",
            group_column_name=_.value,
            row_filter_column_name=__.value,
        )
# Out:
# shape: (24, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬──────────┬───────────┐
# │ used_git_h ┆ current_gi ┆ years_of_e ┆ past_next_ ┆ past_next_ ┆ career_lev ┆ dao_pill ┆ alias     │
# │ osting_pla ┆ t_hosting_ ┆ xperience  ┆ github     ┆ gitlab     ┆ el         ┆ ar       ┆ ---       │
# │ tform      ┆ platform   ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---      ┆ str       │
# │ ---        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        ┆ str      ┆           │
# │ str        ┆ str        ┆            ┆            ┆            ┆            ┆          ┆           │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪══════════╪═══════════╡
# │ GitHub,    ┆ GitHub,    ┆ 4 to 6     ┆ Worked     ┆ Worked     ┆ 2          ┆ Data     ┆ Jeremy    │
# │ GitLab,    ┆ GitLab,    ┆ years      ┆ with in    ┆ with in    ┆            ┆ Admin    ┆           │
# │ Codeberg   ┆ Codeberg   ┆            ┆ PAST       ┆ PAST       ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆          ┆           │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆           │
# │ Bitbucket  ┆ null       ┆ 2 to 4     ┆ Want to    ┆ Want to    ┆ 2          ┆ Data     ┆ Michelle  │
# │            ┆            ┆ years      ┆ work with  ┆ work with  ┆            ┆ Admin    ┆           │
# │            ┆            ┆            ┆ in NEXT    ┆ in NEXT    ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years      ┆ years      ┆            ┆          ┆           │
# │ GitHub,    ┆ GitHub,    ┆ 2 to 4     ┆ Worked     ┆ Worked     ┆ 5          ┆ Data     ┆ Christine │
# │ GitLab     ┆ GitLab     ┆ years      ┆ with in    ┆ with in    ┆            ┆ Admin    ┆           │
# │            ┆            ┆            ┆ PAST       ┆ PAST       ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆          ┆           │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆           │
# │ Bitbucket  ┆ null       ┆ <2 years   ┆ Want to    ┆ Want to    ┆ 4          ┆ Data     ┆ Megan     │
# │            ┆            ┆            ┆ work with  ┆ work with  ┆            ┆ Admin    ┆           │
# │            ┆            ┆            ┆ in NEXT    ┆ in NEXT    ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years      ┆ years      ┆            ┆          ┆           │
# │ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …        ┆ …         │
# │ bitbucker  ┆ bitbucket  ┆ <2 years   ┆ Want to    ┆ Want to    ┆ 4          ┆ Data     ┆ Shaun     │
# │            ┆            ┆            ┆ work with  ┆ work with  ┆            ┆ Admin    ┆           │
# │            ┆            ┆            ┆ in NEXT    ┆ in NEXT    ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years      ┆ years      ┆            ┆          ┆           │
# │ GitHub     ┆ GitHub     ┆ <2 years   ┆ Worked     ┆ Want to    ┆ 2          ┆ Data     ┆ Mackenzie │
# │            ┆            ┆            ┆ with in    ┆ work with  ┆            ┆ Admin    ┆           │
# │            ┆            ┆            ┆ PAST       ┆ in NEXT    ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years,     ┆ years      ┆            ┆          ┆           │
# │            ┆            ┆            ┆ Want …     ┆            ┆            ┆          ┆           │
# │ GitHub     ┆ null       ┆ <2 years   ┆ Worked     ┆ Want to    ┆ 2          ┆ Data     ┆ William   │
# │            ┆            ┆            ┆ with in    ┆ work with  ┆            ┆ Admin    ┆           │
# │            ┆            ┆            ┆ PAST       ┆ in NEXT    ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years,     ┆ years      ┆            ┆          ┆           │
# │            ┆            ┆            ┆ Want …     ┆            ┆            ┆          ┆           │
# │ Git only   ┆ null       ┆ <2 years   ┆ Want to    ┆ Want to    ┆ 2          ┆ Data     ┆ Kenneth   │
# │            ┆            ┆            ┆ work with  ┆ work with  ┆            ┆ Admin    ┆           │
# │            ┆            ┆            ┆ in NEXT    ┆ in NEXT    ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years      ┆ years      ┆            ┆          ┆           │
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴──────────┴───────────┘
# shape: (58, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬──────────┬──────────┐
# │ used_git_h ┆ current_gi ┆ years_of_e ┆ past_next_ ┆ past_next_ ┆ career_lev ┆ dao_pill ┆ alias    │
# │ osting_pla ┆ t_hosting_ ┆ xperience  ┆ github     ┆ gitlab     ┆ el         ┆ ar       ┆ ---      │
# │ tform      ┆ platform   ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---      ┆ str      │
# │ ---        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        ┆ str      ┆          │
# │ str        ┆ str        ┆            ┆            ┆            ┆            ┆          ┆          │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪══════════╪══════════╡
# │ GitHub,    ┆ GitHub,    ┆ 2 to 4     ┆ Worked     ┆ Worked     ┆ 2          ┆ Data Eng ┆ Paul     │
# │ GitLab     ┆ GitLab     ┆ years      ┆ with in    ┆ with in    ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ PAST       ┆ PAST       ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆          ┆          │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆          │
# │ GitLab     ┆ null       ┆ <2 years   ┆ Want to    ┆ Worked     ┆ 2          ┆ Data Eng ┆ Benjamin │
# │            ┆            ┆            ┆ work with  ┆ with in    ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ in NEXT    ┆ PAST       ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years      ┆ years,     ┆            ┆          ┆          │
# │            ┆            ┆            ┆            ┆ Want …     ┆            ┆          ┆          │
# │ GitHub     ┆ GitHub     ┆ 2 to 4     ┆ Worked     ┆ Want to    ┆ 1          ┆ Data Eng ┆ David    │
# │            ┆            ┆ years      ┆ with in    ┆ work with  ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ PAST       ┆ in NEXT    ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years,     ┆ years      ┆            ┆          ┆          │
# │            ┆            ┆            ┆ Want …     ┆            ┆            ┆          ┆          │
# │ GitHub     ┆ GitHub     ┆ 2 to 4     ┆ Worked     ┆ Want to    ┆ 1          ┆ Data Eng ┆ Stacie   │
# │            ┆            ┆ years      ┆ with in    ┆ work with  ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ PAST       ┆ in NEXT    ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years,     ┆ years      ┆            ┆          ┆          │
# │            ┆            ┆            ┆ Want …     ┆            ┆            ┆          ┆          │
# │ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …        ┆ …        │
# │ GitLab     ┆ GitLab     ┆ <2 years   ┆ Want to    ┆ Worked     ┆ 3          ┆ Data Eng ┆ Cody     │
# │            ┆            ┆            ┆ work with  ┆ with in    ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ in NEXT    ┆ PAST       ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years      ┆ years,     ┆            ┆          ┆          │
# │            ┆            ┆            ┆            ┆ Want …     ┆            ┆          ┆          │
# │ GitLab     ┆ null       ┆ <2 years   ┆ Want to    ┆ Worked     ┆ 2          ┆ Data Eng ┆ Joshua   │
# │            ┆            ┆            ┆ work with  ┆ with in    ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ in NEXT    ┆ PAST       ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years      ┆ years,     ┆            ┆          ┆          │
# │            ┆            ┆            ┆            ┆ Want …     ┆            ┆          ┆          │
# │ GitLab     ┆ GitLab     ┆ <2 years   ┆ Want to    ┆ Worked     ┆ 2          ┆ Data Eng ┆ Sarah    │
# │            ┆            ┆            ┆ work with  ┆ with in    ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ in NEXT    ┆ PAST       ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years      ┆ years,     ┆            ┆          ┆          │
# │            ┆            ┆            ┆            ┆ Want …     ┆            ┆          ┆          │
# │ GitHub     ┆ GitHub     ┆ <2 years   ┆ Worked     ┆ Want to    ┆ 2          ┆ Data Eng ┆ Caleb    │
# │            ┆            ┆            ┆ with in    ┆ work with  ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ PAST       ┆ in NEXT    ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years,     ┆ years      ┆            ┆          ┆          │
# │            ┆            ┆            ┆ Want …     ┆            ┆            ┆          ┆          │
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴──────────┴──────────┘
# shape: (19, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬──────────┬──────────┐
# │ used_git_h ┆ current_gi ┆ years_of_e ┆ past_next_ ┆ past_next_ ┆ career_lev ┆ dao_pill ┆ alias    │
# │ osting_pla ┆ t_hosting_ ┆ xperience  ┆ github     ┆ gitlab     ┆ el         ┆ ar       ┆ ---      │
# │ tform      ┆ platform   ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---      ┆ str      │
# │ ---        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        ┆ str      ┆          │
# │ str        ┆ str        ┆            ┆            ┆            ┆            ┆          ┆          │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪══════════╪══════════╡
# │ null       ┆ null       ┆ null       ┆ Want to    ┆ Want to    ┆ 2          ┆ Data     ┆ Victoria │
# │            ┆            ┆            ┆ work with  ┆ work with  ┆            ┆ Science  ┆          │
# │            ┆            ┆            ┆ in NEXT    ┆ in NEXT    ┆            ┆ & Analyt ┆          │
# │            ┆            ┆            ┆ years      ┆ years      ┆            ┆ ics      ┆          │
# │ null       ┆ null       ┆ null       ┆ Want to    ┆ Want to    ┆ 2          ┆ Data     ┆ Adrienne │
# │            ┆            ┆            ┆ work with  ┆ work with  ┆            ┆ Science  ┆          │
# │            ┆            ┆            ┆ in NEXT    ┆ in NEXT    ┆            ┆ & Analyt ┆          │
# │            ┆            ┆            ┆ years      ┆ years      ┆            ┆ ics      ┆          │
# │ GitHub,    ┆ GitHub,    ┆ 2 to 4     ┆ Worked     ┆ Worked     ┆ 3          ┆ Data     ┆ Anthony  │
# │ GitLab     ┆ GitLab     ┆ years      ┆ with in    ┆ with in    ┆            ┆ Science  ┆          │
# │            ┆            ┆            ┆ PAST       ┆ PAST       ┆            ┆ & Analyt ┆          │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆ ics      ┆          │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆          │
# │ GitHub,    ┆ GitHub,    ┆ <2 years   ┆ Worked     ┆ Worked     ┆ 5          ┆ Data     ┆ Brooke   │
# │ GitLab     ┆ GitLab     ┆            ┆ with in    ┆ with in    ┆            ┆ Science  ┆          │
# │            ┆            ┆            ┆ PAST       ┆ PAST       ┆            ┆ & Analyt ┆          │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆ ics      ┆          │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆          │
# │ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …        ┆ …        │
# │ GitHub     ┆ null       ┆ 2 to 4     ┆ Worked     ┆ Want to    ┆ 3          ┆ Data     ┆ Michele  │
# │            ┆            ┆ years      ┆ with in    ┆ work with  ┆            ┆ Science  ┆          │
# │            ┆            ┆            ┆ PAST       ┆ in NEXT    ┆            ┆ & Analyt ┆          │
# │            ┆            ┆            ┆ years,     ┆ years      ┆            ┆ ics      ┆          │
# │            ┆            ┆            ┆ Want …     ┆            ┆            ┆          ┆          │
# │ null       ┆ null       ┆ null       ┆ null       ┆ null       ┆ 2          ┆ Data     ┆ Barbara  │
# │            ┆            ┆            ┆            ┆            ┆            ┆ Science  ┆          │
# │            ┆            ┆            ┆            ┆            ┆            ┆ & Analyt ┆          │
# │            ┆            ┆            ┆            ┆            ┆            ┆ ics      ┆          │
# │ null       ┆ GitHub     ┆ null       ┆ Want to    ┆ Want to    ┆ 4          ┆ Data     ┆ Ricardo  │
# │            ┆            ┆            ┆ work with  ┆ work with  ┆            ┆ Science  ┆          │
# │            ┆            ┆            ┆ in NEXT    ┆ in NEXT    ┆            ┆ & Analyt ┆          │
# │            ┆            ┆            ┆ years      ┆ years      ┆            ┆ ics      ┆          │
# │ null       ┆ null       ┆ null       ┆ null       ┆ null       ┆ 2          ┆ Data     ┆ Linda    │
# │            ┆            ┆            ┆            ┆            ┆            ┆ Science  ┆          │
# │            ┆            ┆            ┆            ┆            ┆            ┆ & Analyt ┆          │
# │            ┆            ┆            ┆            ┆            ┆            ┆ ics      ┆          │
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴──────────┴──────────┘
# shape: (4, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬──────────┬─────────┐
# │ used_git_h ┆ current_gi ┆ years_of_e ┆ past_next_ ┆ past_next_ ┆ career_lev ┆ dao_pill ┆ alias   │
# │ osting_pla ┆ t_hosting_ ┆ xperience  ┆ github     ┆ gitlab     ┆ el         ┆ ar       ┆ ---     │
# │ tform      ┆ platform   ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---      ┆ str     │
# │ ---        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        ┆ str      ┆         │
# │ str        ┆ str        ┆            ┆            ┆            ┆            ┆          ┆         │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪══════════╪═════════╡
# │ GitLab     ┆ GitLab     ┆ <2 years   ┆ Want to    ┆ Worked     ┆ 5          ┆ AFC      ┆ Jessica │
# │            ┆            ┆            ┆ work with  ┆ with in    ┆            ┆          ┆         │
# │            ┆            ┆            ┆ in NEXT    ┆ PAST       ┆            ┆          ┆         │
# │            ┆            ┆            ┆ years      ┆ years,     ┆            ┆          ┆         │
# │            ┆            ┆            ┆            ┆ Want …     ┆            ┆          ┆         │
# │ GitHub,    ┆ GitLab     ┆ <2 years   ┆ Worked     ┆ Worked     ┆ 3          ┆ AFC      ┆ John    │
# │ GitLab     ┆            ┆            ┆ with in    ┆ with in    ┆            ┆          ┆         │
# │            ┆            ┆            ┆ PAST years ┆ PAST       ┆            ┆          ┆         │
# │            ┆            ┆            ┆            ┆ years,     ┆            ┆          ┆         │
# │            ┆            ┆            ┆            ┆ Want …     ┆            ┆          ┆         │
# │ GitLab     ┆ GitLab     ┆ <2 years   ┆ Want to    ┆ Worked     ┆ 5          ┆ AFC      ┆ Gary    │
# │            ┆            ┆            ┆ work with  ┆ with in    ┆            ┆          ┆         │
# │            ┆            ┆            ┆ in NEXT    ┆ PAST       ┆            ┆          ┆         │
# │            ┆            ┆            ┆ years      ┆ years,     ┆            ┆          ┆         │
# │            ┆            ┆            ┆            ┆ Want …     ┆            ┆          ┆         │
# │ GitLab     ┆ GitLab     ┆ 2 to 4     ┆ Want to    ┆ Worked     ┆ 4          ┆ AFC      ┆ Robin   │
# │            ┆            ┆ years      ┆ work with  ┆ with in    ┆            ┆          ┆         │
# │            ┆            ┆            ┆ in NEXT    ┆ PAST       ┆            ┆          ┆         │
# │            ┆            ┆            ┆ years      ┆ years,     ┆            ┆          ┆         │
# │            ┆            ┆            ┆            ┆ Want …     ┆            ┆          ┆         │
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴──────────┴─────────┘
# shape: (0, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────┐
# │ used_git_h ┆ current_gi ┆ years_of_e ┆ past_next_ ┆ past_next_ ┆ career_lev ┆ dao_pillar ┆ alias │
# │ osting_pla ┆ t_hosting_ ┆ xperience  ┆ github     ┆ gitlab     ┆ el         ┆ ---        ┆ ---   │
# │ tform      ┆ platform   ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ str        ┆ str   │
# │ ---        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        ┆            ┆       │
# │ str        ┆ str        ┆            ┆            ┆            ┆            ┆            ┆       │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════╡
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────┘

# %%
for _ in Eyears_of_experience:
    df_tmp: pl.DataFrame = df.filter(pl.col("years_of_experience") == _.value).head()
    print(df_tmp)

    ## Skip filtered empty dataframes
    if df_tmp.is_empty():
        continue

    ## Value Count Column: dao_pillar
    ## Group Column: years_of_experience
    ## Row Filter Column: career_level
    for __ in Ecareer_level:
        df_tmp_bar: pl.DataFrame = df_tmp.filter(pl.col("career_level") == __.value)
        if df_tmp_bar.is_empty():
            continue
        bar_maker(
            df=df_tmp_bar,
            value_counts_column_name="dao_pillar",
            group_column_name=_.value,
            row_filter_column_name=__.value,
        )
# Out:
# shape: (5, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬──────────┬──────────┐
# │ used_git_h ┆ current_gi ┆ years_of_e ┆ past_next_ ┆ past_next_ ┆ career_lev ┆ dao_pill ┆ alias    │
# │ osting_pla ┆ t_hosting_ ┆ xperience  ┆ github     ┆ gitlab     ┆ el         ┆ ar       ┆ ---      │
# │ tform      ┆ platform   ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---      ┆ str      │
# │ ---        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        ┆ str      ┆          │
# │ str        ┆ str        ┆            ┆            ┆            ┆            ┆          ┆          │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪══════════╪══════════╡
# │ GitLab     ┆ null       ┆ <2 years   ┆ Want to    ┆ Worked     ┆ 2          ┆ Data Eng ┆ Benjamin │
# │            ┆            ┆            ┆ work with  ┆ with in    ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ in NEXT    ┆ PAST       ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years      ┆ years,     ┆            ┆          ┆          │
# │            ┆            ┆            ┆            ┆ Want …     ┆            ┆          ┆          │
# │ Bitbucket  ┆ null       ┆ <2 years   ┆ Want to    ┆ Want to    ┆ 4          ┆ Data     ┆ Megan    │
# │            ┆            ┆            ┆ work with  ┆ work with  ┆            ┆ Admin    ┆          │
# │            ┆            ┆            ┆ in NEXT    ┆ in NEXT    ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years      ┆ years      ┆            ┆          ┆          │
# │ GitHub,    ┆ GitHub     ┆ <2 years   ┆ Worked     ┆ Worked     ┆ 3          ┆ Data     ┆ Natalie  │
# │ GitLab     ┆            ┆            ┆ with in    ┆ with in    ┆            ┆ Admin    ┆          │
# │            ┆            ┆            ┆ PAST       ┆ PAST       ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆          ┆          │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆          │
# │ GitHub     ┆ GitHub     ┆ <2 years   ┆ Worked     ┆ Want to    ┆ 1          ┆ Data Eng ┆ James    │
# │            ┆            ┆            ┆ with in    ┆ work with  ┆            ┆ ineering ┆          │
# │            ┆            ┆            ┆ PAST       ┆ in NEXT    ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years,     ┆ years      ┆            ┆          ┆          │
# │            ┆            ┆            ┆ Want …     ┆            ┆            ┆          ┆          │
# │ GitHub,    ┆ Bitbucket  ┆ <2 years   ┆ Worked     ┆ Worked     ┆ 2          ┆ Data Eng ┆ Jean     │
# │ GitLab,    ┆            ┆            ┆ with in    ┆ with in    ┆            ┆ ineering ┆          │
# │ Bitbucket  ┆            ┆            ┆ PAST       ┆ PAST       ┆            ┆          ┆          │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆          ┆          │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆          │
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴──────────┴──────────┘
# shape: (5, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬──────────┬───────────┐
# │ used_git_h ┆ current_gi ┆ years_of_e ┆ past_next_ ┆ past_next_ ┆ career_lev ┆ dao_pill ┆ alias     │
# │ osting_pla ┆ t_hosting_ ┆ xperience  ┆ github     ┆ gitlab     ┆ el         ┆ ar       ┆ ---       │
# │ tform      ┆ platform   ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---      ┆ str       │
# │ ---        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        ┆ str      ┆           │
# │ str        ┆ str        ┆            ┆            ┆            ┆            ┆          ┆           │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪══════════╪═══════════╡
# │ GitHub,    ┆ GitHub,    ┆ 2 to 4     ┆ Worked     ┆ Worked     ┆ 2          ┆ Data Eng ┆ Paul      │
# │ GitLab     ┆ GitLab     ┆ years      ┆ with in    ┆ with in    ┆            ┆ ineering ┆           │
# │            ┆            ┆            ┆ PAST       ┆ PAST       ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆          ┆           │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆           │
# │ GitHub     ┆ GitHub     ┆ 2 to 4     ┆ Worked     ┆ Want to    ┆ 1          ┆ Data Eng ┆ David     │
# │            ┆            ┆ years      ┆ with in    ┆ work with  ┆            ┆ ineering ┆           │
# │            ┆            ┆            ┆ PAST       ┆ in NEXT    ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years,     ┆ years      ┆            ┆          ┆           │
# │            ┆            ┆            ┆ Want …     ┆            ┆            ┆          ┆           │
# │ GitHub     ┆ GitHub     ┆ 2 to 4     ┆ Worked     ┆ Want to    ┆ 1          ┆ Data Eng ┆ Stacie    │
# │            ┆            ┆ years      ┆ with in    ┆ work with  ┆            ┆ ineering ┆           │
# │            ┆            ┆            ┆ PAST       ┆ in NEXT    ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years,     ┆ years      ┆            ┆          ┆           │
# │            ┆            ┆            ┆ Want …     ┆            ┆            ┆          ┆           │
# │ Bitbucket  ┆ null       ┆ 2 to 4     ┆ Want to    ┆ Want to    ┆ 2          ┆ Data     ┆ Michelle  │
# │            ┆            ┆ years      ┆ work with  ┆ work with  ┆            ┆ Admin    ┆           │
# │            ┆            ┆            ┆ in NEXT    ┆ in NEXT    ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years      ┆ years      ┆            ┆          ┆           │
# │ GitHub,    ┆ GitHub,    ┆ 2 to 4     ┆ Worked     ┆ Worked     ┆ 5          ┆ Data     ┆ Christine │
# │ GitLab     ┆ GitLab     ┆ years      ┆ with in    ┆ with in    ┆            ┆ Admin    ┆           │
# │            ┆            ┆            ┆ PAST       ┆ PAST       ┆            ┆          ┆           │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆          ┆           │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆           │
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴──────────┴───────────┘
# shape: (5, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬──────────┬─────────┐
# │ used_git_h ┆ current_gi ┆ years_of_e ┆ past_next_ ┆ past_next_ ┆ career_lev ┆ dao_pill ┆ alias   │
# │ osting_pla ┆ t_hosting_ ┆ xperience  ┆ github     ┆ gitlab     ┆ el         ┆ ar       ┆ ---     │
# │ tform      ┆ platform   ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---      ┆ str     │
# │ ---        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        ┆ str      ┆         │
# │ str        ┆ str        ┆            ┆            ┆            ┆            ┆          ┆         │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪══════════╪═════════╡
# │ GitHub,    ┆ GitHub,    ┆ 4 to 6     ┆ Worked     ┆ Worked     ┆ 2          ┆ Data     ┆ Jeremy  │
# │ GitLab,    ┆ GitLab,    ┆ years      ┆ with in    ┆ with in    ┆            ┆ Admin    ┆         │
# │ Codeberg   ┆ Codeberg   ┆            ┆ PAST       ┆ PAST       ┆            ┆          ┆         │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆          ┆         │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆         │
# │ GitHub,    ┆ GitLab     ┆ 4 to 6     ┆ Worked     ┆ Worked     ┆ 4          ┆ Data Eng ┆ Scott   │
# │ GitLab     ┆            ┆ years      ┆ with in    ┆ with in    ┆            ┆ ineering ┆         │
# │            ┆            ┆            ┆ PAST years ┆ PAST       ┆            ┆          ┆         │
# │            ┆            ┆            ┆            ┆ years,     ┆            ┆          ┆         │
# │            ┆            ┆            ┆            ┆ Want …     ┆            ┆          ┆         │
# │ GitHub,    ┆ GitHub,    ┆ 4 to 6     ┆ Worked     ┆ Want to    ┆ 2          ┆ Data Eng ┆ Bryan   │
# │ Bitbucket  ┆ Bitbucket  ┆ years      ┆ with in    ┆ work with  ┆            ┆ ineering ┆         │
# │            ┆            ┆            ┆ PAST       ┆ in NEXT    ┆            ┆          ┆         │
# │            ┆            ┆            ┆ years,     ┆ years      ┆            ┆          ┆         │
# │            ┆            ┆            ┆ Want …     ┆            ┆            ┆          ┆         │
# │ GitHub,    ┆ GitHub     ┆ 4 to 6     ┆ Worked     ┆ Worked     ┆ 2          ┆ Data Eng ┆ Alfred  │
# │ GitLab     ┆            ┆ years      ┆ with in    ┆ with in    ┆            ┆ ineering ┆         │
# │            ┆            ┆            ┆ PAST       ┆ PAST       ┆            ┆          ┆         │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆          ┆         │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆          ┆         │
# │ GitHub,    ┆ GitLab     ┆ 4 to 6     ┆ Worked     ┆ Worked     ┆ 3          ┆ Data Eng ┆ Abigail │
# │ GitLab     ┆            ┆ years      ┆ with in    ┆ with in    ┆            ┆ ineering ┆         │
# │            ┆            ┆            ┆ PAST years ┆ PAST       ┆            ┆          ┆         │
# │            ┆            ┆            ┆            ┆ years,     ┆            ┆          ┆         │
# │            ┆            ┆            ┆            ┆ Want …     ┆            ┆          ┆         │
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴──────────┴─────────┘
# shape: (1, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────┐
# │ used_git_h ┆ current_gi ┆ years_of_e ┆ past_next_ ┆ past_next_ ┆ career_lev ┆ dao_pillar ┆ alias │
# │ osting_pla ┆ t_hosting_ ┆ xperience  ┆ github     ┆ gitlab     ┆ el         ┆ ---        ┆ ---   │
# │ tform      ┆ platform   ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ str        ┆ str   │
# │ ---        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        ┆            ┆       │
# │ str        ┆ str        ┆            ┆            ┆            ┆            ┆            ┆       │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════╡
# │ GitHub,    ┆ GitLab     ┆ 8 to 10    ┆ Worked     ┆ Worked     ┆ 5          ┆ Data Engin ┆ Chris │
# │ GitLab     ┆            ┆ years      ┆ with in    ┆ with in    ┆            ┆ eering     ┆       │
# │            ┆            ┆            ┆ PAST       ┆ PAST       ┆            ┆            ┆       │
# │            ┆            ┆            ┆ years,     ┆ years,     ┆            ┆            ┆       │
# │            ┆            ┆            ┆ Want …     ┆ Want …     ┆            ┆            ┆       │
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────┘
# shape: (0, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────┐
# │ used_git_h ┆ current_gi ┆ years_of_e ┆ past_next_ ┆ past_next_ ┆ career_lev ┆ dao_pillar ┆ alias │
# │ osting_pla ┆ t_hosting_ ┆ xperience  ┆ github     ┆ gitlab     ┆ el         ┆ ---        ┆ ---   │
# │ tform      ┆ platform   ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ str        ┆ str   │
# │ ---        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ str        ┆            ┆       │
# │ str        ┆ str        ┆            ┆            ┆            ┆            ┆            ┆       │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════╡
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────┘

# %%
# Combine value counts parquets
# TODO: DRY code

path_bar_parquet: Path = output_data_path / "Bar Diagrams" / "dao_pillar" / "parquet"

df_tmp: pl.DataFrame = pl.DataFrame(
    schema={
        "dao_pillar": pl.Utf8,
        "counts": pl.Float64,
        "group": pl.Utf8,
        "row_filter": pl.Utf8,
    }
)

for _ in path_bar_parquet.glob("**/bar-dao_pillar-*.parquet"):
    with _ as file:
        df_pq = pl.read_parquet(
            source=file, use_pyarrow=True
        )  # .with_columns(pl.col("counts").cast(pl.Float32))
        print(df_pq)
        df_tmp.extend(df_pq)
    # df_tmp.extend(df_tmp_tmp)

df_tmp  # .head()
df_tmp.write_json(
    file=output_data_path / "Bar Diagrams" / "dao_pillar" / "bar-dao_pillar-main.json",
    pretty=True,
    row_oriented=True,
)
# Out:
# shape: (4, 4)
# ┌──────────────────────────┬────────┬─────────────────┬─────────────────┐
# │ dao_pillar               ┆ counts ┆ group           ┆ row_filter      │
# │ ---                      ┆ ---    ┆ ---             ┆ ---             │
# │ str                      ┆ f64    ┆ str             ┆ str             │
# ╞══════════════════════════╪════════╪═════════════════╪═════════════════╡
# │ Data Engineering         ┆ 55.24  ┆ All respondents ┆ All respondents │
# │ Data Admin               ┆ 22.86  ┆ All respondents ┆ All respondents │
# │ Data Science & Analytics ┆ 18.1   ┆ All respondents ┆ All respondents │
# │ AFC                      ┆ 3.81   ┆ All respondents ┆ All respondents │
# └──────────────────────────┴────────┴─────────────────┴─────────────────┘
# shape: (1, 4)
# ┌──────────────────┬────────┬──────────┬────────────┐
# │ dao_pillar       ┆ counts ┆ group    ┆ row_filter │
# │ ---              ┆ ---    ┆ ---      ┆ ---        │
# │ str              ┆ f64    ┆ str      ┆ str        │
# ╞══════════════════╪════════╪══════════╪════════════╡
# │ Data Engineering ┆ 100.0  ┆ <2 years ┆ 1          │
# └──────────────────┴────────┴──────────┴────────────┘
# shape: (1, 4)
# ┌──────────────────┬────────┬──────────┬────────────┐
# │ dao_pillar       ┆ counts ┆ group    ┆ row_filter │
# │ ---              ┆ ---    ┆ ---      ┆ ---        │
# │ str              ┆ f64    ┆ str      ┆ str        │
# ╞══════════════════╪════════╪══════════╪════════════╡
# │ Data Engineering ┆ 100.0  ┆ <2 years ┆ 2          │
# └──────────────────┴────────┴──────────┴────────────┘
# shape: (1, 4)
# ┌────────────┬────────┬──────────┬────────────┐
# │ dao_pillar ┆ counts ┆ group    ┆ row_filter │
# │ ---        ┆ ---    ┆ ---      ┆ ---        │
# │ str        ┆ f64    ┆ str      ┆ str        │
# ╞════════════╪════════╪══════════╪════════════╡
# │ Data Admin ┆ 100.0  ┆ <2 years ┆ 3          │
# └────────────┴────────┴──────────┴────────────┘
# shape: (1, 4)
# ┌────────────┬────────┬──────────┬────────────┐
# │ dao_pillar ┆ counts ┆ group    ┆ row_filter │
# │ ---        ┆ ---    ┆ ---      ┆ ---        │
# │ str        ┆ f64    ┆ str      ┆ str        │
# ╞════════════╪════════╪══════════╪════════════╡
# │ Data Admin ┆ 100.0  ┆ <2 years ┆ 4          │
# └────────────┴────────┴──────────┴────────────┘
# shape: (1, 4)
# ┌──────────────────┬────────┬──────────────┬────────────┐
# │ dao_pillar       ┆ counts ┆ group        ┆ row_filter │
# │ ---              ┆ ---    ┆ ---          ┆ ---        │
# │ str              ┆ f64    ┆ str          ┆ str        │
# ╞══════════════════╪════════╪══════════════╪════════════╡
# │ Data Engineering ┆ 100.0  ┆ 2 to 4 years ┆ 1          │
# └──────────────────┴────────┴──────────────┴────────────┘
# shape: (2, 4)
# ┌──────────────────┬────────┬──────────────┬────────────┐
# │ dao_pillar       ┆ counts ┆ group        ┆ row_filter │
# │ ---              ┆ ---    ┆ ---          ┆ ---        │
# │ str              ┆ f64    ┆ str          ┆ str        │
# ╞══════════════════╪════════╪══════════════╪════════════╡
# │ Data Admin       ┆ 50.0   ┆ 2 to 4 years ┆ 2          │
# │ Data Engineering ┆ 50.0   ┆ 2 to 4 years ┆ 2          │
# └──────────────────┴────────┴──────────────┴────────────┘
# shape: (1, 4)
# ┌────────────┬────────┬──────────────┬────────────┐
# │ dao_pillar ┆ counts ┆ group        ┆ row_filter │
# │ ---        ┆ ---    ┆ ---          ┆ ---        │
# │ str        ┆ f64    ┆ str          ┆ str        │
# ╞════════════╪════════╪══════════════╪════════════╡
# │ Data Admin ┆ 100.0  ┆ 2 to 4 years ┆ 5          │
# └────────────┴────────┴──────────────┴────────────┘
# shape: (2, 4)
# ┌──────────────────┬────────┬──────────────┬────────────┐
# │ dao_pillar       ┆ counts ┆ group        ┆ row_filter │
# │ ---              ┆ ---    ┆ ---          ┆ ---        │
# │ str              ┆ f64    ┆ str          ┆ str        │
# ╞══════════════════╪════════╪══════════════╪════════════╡
# │ Data Engineering ┆ 66.67  ┆ 4 to 6 years ┆ 2          │
# │ Data Admin       ┆ 33.33  ┆ 4 to 6 years ┆ 2          │
# └──────────────────┴────────┴──────────────┴────────────┘
# shape: (1, 4)
# ┌──────────────────┬────────┬──────────────┬────────────┐
# │ dao_pillar       ┆ counts ┆ group        ┆ row_filter │
# │ ---              ┆ ---    ┆ ---          ┆ ---        │
# │ str              ┆ f64    ┆ str          ┆ str        │
# ╞══════════════════╪════════╪══════════════╪════════════╡
# │ Data Engineering ┆ 100.0  ┆ 4 to 6 years ┆ 3          │
# └──────────────────┴────────┴──────────────┴────────────┘
# shape: (1, 4)
# ┌──────────────────┬────────┬──────────────┬────────────┐
# │ dao_pillar       ┆ counts ┆ group        ┆ row_filter │
# │ ---              ┆ ---    ┆ ---          ┆ ---        │
# │ str              ┆ f64    ┆ str          ┆ str        │
# ╞══════════════════╪════════╪══════════════╪════════════╡
# │ Data Engineering ┆ 100.0  ┆ 4 to 6 years ┆ 4          │
# └──────────────────┴────────┴──────────────┴────────────┘
# shape: (1, 4)
# ┌──────────────────┬────────┬───────────────┬────────────┐
# │ dao_pillar       ┆ counts ┆ group         ┆ row_filter │
# │ ---              ┆ ---    ┆ ---           ┆ ---        │
# │ str              ┆ f64    ┆ str           ┆ str        │
# ╞══════════════════╪════════╪═══════════════╪════════════╡
# │ Data Engineering ┆ 100.0  ┆ 8 to 10 years ┆ 5          │
# └──────────────────┴────────┴───────────────┴────────────┘

# %%
# Combine value counts parquets

path_bar_parquet: Path = (
    output_data_path / "Bar Diagrams" / "years_of_experience" / "parquet"
)

df_tmp: pl.DataFrame = pl.DataFrame(
    schema={
        "years_of_experience": pl.Utf8,
        "counts": pl.Float64,
        "group": pl.Utf8,
        "row_filter": pl.Utf8,
    }
)

print(df_tmp)

for _ in path_bar_parquet.glob("**/bar-years_of_experience-*.parquet"):
    with _ as file:
        df_pq = pl.read_parquet(
            source=file, use_pyarrow=True
        )  # .with_columns(pl.col("counts").cast(pl.Float32))
        print(df_pq)
        df_tmp.extend(df_pq)
    # df_tmp.extend(df_tmp_tmp)

df_tmp  # .head()
df_tmp.write_json(
    file=output_data_path
    / "Bar Diagrams"
    / "years_of_experience"
    / "bar-years_of_experience-main.json",
    pretty=True,
    row_oriented=True,
)
# Out:
# shape: (0, 4)
# ┌─────────────────────┬────────┬───────┬────────────┐
# │ years_of_experience ┆ counts ┆ group ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---   ┆ ---        │
# │ str                 ┆ f64    ┆ str   ┆ str        │
# ╞═════════════════════╪════════╪═══════╪════════════╡
# └─────────────────────┴────────┴───────┴────────────┘
# shape: (5, 4)
# ┌─────────────────────┬────────┬─────────────────┬─────────────────┐
# │ years_of_experience ┆ counts ┆ group           ┆ row_filter      │
# │ ---                 ┆ ---    ┆ ---             ┆ ---             │
# │ str                 ┆ f64    ┆ str             ┆ str             │
# ╞═════════════════════╪════════╪═════════════════╪═════════════════╡
# │ <2 years            ┆ 52.38  ┆ All respondents ┆ All respondents │
# │ 2 to 4 years        ┆ 26.67  ┆ All respondents ┆ All respondents │
# │ None                ┆ 14.29  ┆ All respondents ┆ All respondents │
# │ 4 to 6 years        ┆ 5.71   ┆ All respondents ┆ All respondents │
# │ 8 to 10 years       ┆ 0.95   ┆ All respondents ┆ All respondents │
# └─────────────────────┴────────┴─────────────────┴─────────────────┘
# shape: (3, 4)
# ┌─────────────────────┬────────┬────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group      ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---        ┆ ---        │
# │ str                 ┆ f64    ┆ str        ┆ str        │
# ╞═════════════════════╪════════╪════════════╪════════════╡
# │ <2 years            ┆ 61.54  ┆ Data Admin ┆ 2          │
# │ 2 to 4 years        ┆ 30.77  ┆ Data Admin ┆ 2          │
# │ 4 to 6 years        ┆ 7.69   ┆ Data Admin ┆ 2          │
# └─────────────────────┴────────┴────────────┴────────────┘
# shape: (2, 4)
# ┌─────────────────────┬────────┬────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group      ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---        ┆ ---        │
# │ str                 ┆ f64    ┆ str        ┆ str        │
# ╞═════════════════════╪════════╪════════════╪════════════╡
# │ <2 years            ┆ 66.67  ┆ Data Admin ┆ 3          │
# │ 2 to 4 years        ┆ 33.33  ┆ Data Admin ┆ 3          │
# └─────────────────────┴────────┴────────────┴────────────┘
# shape: (1, 4)
# ┌─────────────────────┬────────┬────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group      ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---        ┆ ---        │
# │ str                 ┆ f64    ┆ str        ┆ str        │
# ╞═════════════════════╪════════╪════════════╪════════════╡
# │ <2 years            ┆ 100.0  ┆ Data Admin ┆ 4          │
# └─────────────────────┴────────┴────────────┴────────────┘
# shape: (2, 4)
# ┌─────────────────────┬────────┬────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group      ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---        ┆ ---        │
# │ str                 ┆ f64    ┆ str        ┆ str        │
# ╞═════════════════════╪════════╪════════════╪════════════╡
# │ 2 to 4 years        ┆ 66.67  ┆ Data Admin ┆ 5          │
# │ <2 years            ┆ 33.33  ┆ Data Admin ┆ 5          │
# └─────────────────────┴────────┴────────────┴────────────┘
# shape: (2, 4)
# ┌─────────────────────┬────────┬──────────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group            ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---              ┆ ---        │
# │ str                 ┆ f64    ┆ str              ┆ str        │
# ╞═════════════════════╪════════╪══════════════════╪════════════╡
# │ <2 years            ┆ 75.0   ┆ Data Engineering ┆ 1          │
# │ 2 to 4 years        ┆ 25.0   ┆ Data Engineering ┆ 1          │
# └─────────────────────┴────────┴──────────────────┴────────────┘
# shape: (4, 4)
# ┌─────────────────────┬────────┬──────────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group            ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---              ┆ ---        │
# │ str                 ┆ f64    ┆ str              ┆ str        │
# ╞═════════════════════╪════════╪══════════════════╪════════════╡
# │ <2 years            ┆ 57.14  ┆ Data Engineering ┆ 2          │
# │ 2 to 4 years        ┆ 25.0   ┆ Data Engineering ┆ 2          │
# │ None                ┆ 10.71  ┆ Data Engineering ┆ 2          │
# │ 4 to 6 years        ┆ 7.14   ┆ Data Engineering ┆ 2          │
# └─────────────────────┴────────┴──────────────────┴────────────┘
# shape: (4, 4)
# ┌─────────────────────┬────────┬──────────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group            ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---              ┆ ---        │
# │ str                 ┆ f64    ┆ str              ┆ str        │
# ╞═════════════════════╪════════╪══════════════════╪════════════╡
# │ <2 years            ┆ 50.0   ┆ Data Engineering ┆ 3          │
# │ 2 to 4 years        ┆ 25.0   ┆ Data Engineering ┆ 3          │
# │ None                ┆ 16.67  ┆ Data Engineering ┆ 3          │
# │ 4 to 6 years        ┆ 8.33   ┆ Data Engineering ┆ 3          │
# └─────────────────────┴────────┴──────────────────┴────────────┘
# shape: (2, 4)
# ┌─────────────────────┬────────┬──────────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group            ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---              ┆ ---        │
# │ str                 ┆ f64    ┆ str              ┆ str        │
# ╞═════════════════════╪════════╪══════════════════╪════════════╡
# │ 2 to 4 years        ┆ 50.0   ┆ Data Engineering ┆ 4          │
# │ 4 to 6 years        ┆ 50.0   ┆ Data Engineering ┆ 4          │
# └─────────────────────┴────────┴──────────────────┴────────────┘
# shape: (2, 4)
# ┌─────────────────────┬────────┬──────────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group            ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---              ┆ ---        │
# │ str                 ┆ f64    ┆ str              ┆ str        │
# ╞═════════════════════╪════════╪══════════════════╪════════════╡
# │ None                ┆ 50.0   ┆ Data Engineering ┆ 5          │
# │ 8 to 10 years       ┆ 50.0   ┆ Data Engineering ┆ 5          │
# └─────────────────────┴────────┴──────────────────┴────────────┘
# shape: (2, 4)
# ┌─────────────────────┬────────┬──────────────────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group                    ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---                      ┆ ---        │
# │ str                 ┆ f64    ┆ str                      ┆ str        │
# ╞═════════════════════╪════════╪══════════════════════════╪════════════╡
# │ None                ┆ 50.0   ┆ Data Science & Analytics ┆ 1          │
# │ <2 years            ┆ 50.0   ┆ Data Science & Analytics ┆ 1          │
# └─────────────────────┴────────┴──────────────────────────┴────────────┘
# shape: (2, 4)
# ┌─────────────────────┬────────┬──────────────────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group                    ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---                      ┆ ---        │
# │ str                 ┆ f64    ┆ str                      ┆ str        │
# ╞═════════════════════╪════════╪══════════════════════════╪════════════╡
# │ None                ┆ 66.67  ┆ Data Science & Analytics ┆ 2          │
# │ 2 to 4 years        ┆ 33.33  ┆ Data Science & Analytics ┆ 2          │
# └─────────────────────┴────────┴──────────────────────────┴────────────┘
# shape: (3, 4)
# ┌─────────────────────┬────────┬──────────────────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group                    ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---                      ┆ ---        │
# │ str                 ┆ f64    ┆ str                      ┆ str        │
# ╞═════════════════════╪════════╪══════════════════════════╪════════════╡
# │ <2 years            ┆ 42.86  ┆ Data Science & Analytics ┆ 3          │
# │ 2 to 4 years        ┆ 28.57  ┆ Data Science & Analytics ┆ 3          │
# │ None                ┆ 28.57  ┆ Data Science & Analytics ┆ 3          │
# └─────────────────────┴────────┴──────────────────────────┴────────────┘
# shape: (1, 4)
# ┌─────────────────────┬────────┬──────────────────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group                    ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---                      ┆ ---        │
# │ str                 ┆ f64    ┆ str                      ┆ str        │
# ╞═════════════════════╪════════╪══════════════════════════╪════════════╡
# │ None                ┆ 100.0  ┆ Data Science & Analytics ┆ 4          │
# └─────────────────────┴────────┴──────────────────────────┴────────────┘
# shape: (1, 4)
# ┌─────────────────────┬────────┬──────────────────────────┬────────────┐
# │ years_of_experience ┆ counts ┆ group                    ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---                      ┆ ---        │
# │ str                 ┆ f64    ┆ str                      ┆ str        │
# ╞═════════════════════╪════════╪══════════════════════════╪════════════╡
# │ <2 years            ┆ 100.0  ┆ Data Science & Analytics ┆ 5          │
# └─────────────────────┴────────┴──────────────────────────┴────────────┘
# shape: (1, 4)
# ┌─────────────────────┬────────┬───────┬────────────┐
# │ years_of_experience ┆ counts ┆ group ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---   ┆ ---        │
# │ str                 ┆ f64    ┆ str   ┆ str        │
# ╞═════════════════════╪════════╪═══════╪════════════╡
# │ <2 years            ┆ 100.0  ┆ AFC   ┆ 3          │
# └─────────────────────┴────────┴───────┴────────────┘
# shape: (1, 4)
# ┌─────────────────────┬────────┬───────┬────────────┐
# │ years_of_experience ┆ counts ┆ group ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---   ┆ ---        │
# │ str                 ┆ f64    ┆ str   ┆ str        │
# ╞═════════════════════╪════════╪═══════╪════════════╡
# │ 2 to 4 years        ┆ 100.0  ┆ AFC   ┆ 4          │
# └─────────────────────┴────────┴───────┴────────────┘
# shape: (1, 4)
# ┌─────────────────────┬────────┬───────┬────────────┐
# │ years_of_experience ┆ counts ┆ group ┆ row_filter │
# │ ---                 ┆ ---    ┆ ---   ┆ ---        │
# │ str                 ┆ f64    ┆ str   ┆ str        │
# ╞═════════════════════╪════════╪═══════╪════════════╡
# │ <2 years            ┆ 100.0  ┆ AFC   ┆ 5          │
# └─────────────────────┴────────┴───────┴────────────┘

# %%
# Combine value counts parquets

path_bar_parquet: Path = output_data_path / "Bar Diagrams" / "career_level" / "parquet"

df_tmp: pl.DataFrame = pl.DataFrame(
    schema={
        "career_level": pl.Utf8,
        "counts": pl.Float64,
        "group": pl.Utf8,
        "row_filter": pl.Utf8,
    }
)

print(df_tmp)

for _ in path_bar_parquet.glob("**/bar-career_level-*.parquet"):
    with _ as file:
        df_pq = pl.read_parquet(
            source=file, use_pyarrow=True
        )  # .with_columns(pl.col("counts").cast(pl.Float32))
        print(df_pq)
        df_tmp.extend(df_pq)
    # df_tmp.extend(df_tmp_tmp)

df_tmp  # .head()
df_tmp.write_json(
    file=output_data_path
    / "Bar Diagrams"
    / "career_level"
    / "bar-career_level-main.json",
    pretty=True,
    row_oriented=True,
)
# Out:
# shape: (0, 4)
# ┌──────────────┬────────┬───────┬────────────┐
# │ career_level ┆ counts ┆ group ┆ row_filter │
# │ ---          ┆ ---    ┆ ---   ┆ ---        │
# │ str          ┆ f64    ┆ str   ┆ str        │
# ╞══════════════╪════════╪═══════╪════════════╡
# └──────────────┴────────┴───────┴────────────┘
# shape: (5, 4)
# ┌──────────────┬────────┬─────────────────┬─────────────────┐
# │ career_level ┆ counts ┆ group           ┆ row_filter      │
# │ ---          ┆ ---    ┆ ---             ┆ ---             │
# │ str          ┆ f64    ┆ str             ┆ str             │
# ╞══════════════╪════════╪═════════════════╪═════════════════╡
# │ 2            ┆ 44.76  ┆ All respondents ┆ All respondents │
# │ 3            ┆ 24.76  ┆ All respondents ┆ All respondents │
# │ 1            ┆ 15.24  ┆ All respondents ┆ All respondents │
# │ 4            ┆ 7.62   ┆ All respondents ┆ All respondents │
# │ 5            ┆ 7.62   ┆ All respondents ┆ All respondents │
# └──────────────┴────────┴─────────────────┴─────────────────┘
# shape: (4, 4)
# ┌──────────────┬────────┬────────────┬────────────┐
# │ career_level ┆ counts ┆ group      ┆ row_filter │
# │ ---          ┆ ---    ┆ ---        ┆ ---        │
# │ str          ┆ f64    ┆ str        ┆ str        │
# ╞══════════════╪════════╪════════════╪════════════╡
# │ 2            ┆ 53.33  ┆ Data Admin ┆ <2 years   │
# │ 3            ┆ 26.67  ┆ Data Admin ┆ <2 years   │
# │ 4            ┆ 13.33  ┆ Data Admin ┆ <2 years   │
# │ 5            ┆ 6.67   ┆ Data Admin ┆ <2 years   │
# └──────────────┴────────┴────────────┴────────────┘
# shape: (3, 4)
# ┌──────────────┬────────┬────────────┬──────────────┐
# │ career_level ┆ counts ┆ group      ┆ row_filter   │
# │ ---          ┆ ---    ┆ ---        ┆ ---          │
# │ str          ┆ f64    ┆ str        ┆ str          │
# ╞══════════════╪════════╪════════════╪══════════════╡
# │ 2            ┆ 50.0   ┆ Data Admin ┆ 2 to 4 years │
# │ 3            ┆ 25.0   ┆ Data Admin ┆ 2 to 4 years │
# │ 5            ┆ 25.0   ┆ Data Admin ┆ 2 to 4 years │
# └──────────────┴────────┴────────────┴──────────────┘
# shape: (1, 4)
# ┌──────────────┬────────┬────────────┬──────────────┐
# │ career_level ┆ counts ┆ group      ┆ row_filter   │
# │ ---          ┆ ---    ┆ ---        ┆ ---          │
# │ str          ┆ f64    ┆ str        ┆ str          │
# ╞══════════════╪════════╪════════════╪══════════════╡
# │ 2            ┆ 100.0  ┆ Data Admin ┆ 4 to 6 years │
# └──────────────┴────────┴────────────┴──────────────┘
# shape: (3, 4)
# ┌──────────────┬────────┬──────────────────┬────────────┐
# │ career_level ┆ counts ┆ group            ┆ row_filter │
# │ ---          ┆ ---    ┆ ---              ┆ ---        │
# │ str          ┆ f64    ┆ str              ┆ str        │
# ╞══════════════╪════════╪══════════════════╪════════════╡
# │ 2            ┆ 51.61  ┆ Data Engineering ┆ <2 years   │
# │ 1            ┆ 29.03  ┆ Data Engineering ┆ <2 years   │
# │ 3            ┆ 19.35  ┆ Data Engineering ┆ <2 years   │
# └──────────────┴────────┴──────────────────┴────────────┘
# shape: (4, 4)
# ┌──────────────┬────────┬──────────────────┬──────────────┐
# │ career_level ┆ counts ┆ group            ┆ row_filter   │
# │ ---          ┆ ---    ┆ ---              ┆ ---          │
# │ str          ┆ f64    ┆ str              ┆ str          │
# ╞══════════════╪════════╪══════════════════╪══════════════╡
# │ 2            ┆ 46.67  ┆ Data Engineering ┆ 2 to 4 years │
# │ 3            ┆ 20.0   ┆ Data Engineering ┆ 2 to 4 years │
# │ 1            ┆ 20.0   ┆ Data Engineering ┆ 2 to 4 years │
# │ 4            ┆ 13.33  ┆ Data Engineering ┆ 2 to 4 years │
# └──────────────┴────────┴──────────────────┴──────────────┘
# shape: (3, 4)
# ┌──────────────┬────────┬──────────────────┬──────────────┐
# │ career_level ┆ counts ┆ group            ┆ row_filter   │
# │ ---          ┆ ---    ┆ ---              ┆ ---          │
# │ str          ┆ f64    ┆ str              ┆ str          │
# ╞══════════════╪════════╪══════════════════╪══════════════╡
# │ 2            ┆ 40.0   ┆ Data Engineering ┆ 4 to 6 years │
# │ 4            ┆ 40.0   ┆ Data Engineering ┆ 4 to 6 years │
# │ 3            ┆ 20.0   ┆ Data Engineering ┆ 4 to 6 years │
# └──────────────┴────────┴──────────────────┴──────────────┘
# shape: (1, 4)
# ┌──────────────┬────────┬──────────────────┬───────────────┐
# │ career_level ┆ counts ┆ group            ┆ row_filter    │
# │ ---          ┆ ---    ┆ ---              ┆ ---           │
# │ str          ┆ f64    ┆ str              ┆ str           │
# ╞══════════════╪════════╪══════════════════╪═══════════════╡
# │ 5            ┆ 100.0  ┆ Data Engineering ┆ 8 to 10 years │
# └──────────────┴────────┴──────────────────┴───────────────┘
# shape: (3, 4)
# ┌──────────────┬────────┬──────────────────────────┬────────────┐
# │ career_level ┆ counts ┆ group                    ┆ row_filter │
# │ ---          ┆ ---    ┆ ---                      ┆ ---        │
# │ str          ┆ f64    ┆ str                      ┆ str        │
# ╞══════════════╪════════╪══════════════════════════╪════════════╡
# │ 3            ┆ 50.0   ┆ Data Science & Analytics ┆ <2 years   │
# │ 1            ┆ 33.33  ┆ Data Science & Analytics ┆ <2 years   │
# │ 5            ┆ 16.67  ┆ Data Science & Analytics ┆ <2 years   │
# └──────────────┴────────┴──────────────────────────┴────────────┘
# shape: (2, 4)
# ┌──────────────┬────────┬──────────────────────────┬──────────────┐
# │ career_level ┆ counts ┆ group                    ┆ row_filter   │
# │ ---          ┆ ---    ┆ ---                      ┆ ---          │
# │ str          ┆ f64    ┆ str                      ┆ str          │
# ╞══════════════╪════════╪══════════════════════════╪══════════════╡
# │ 3            ┆ 50.0   ┆ Data Science & Analytics ┆ 2 to 4 years │
# │ 2            ┆ 50.0   ┆ Data Science & Analytics ┆ 2 to 4 years │
# └──────────────┴────────┴──────────────────────────┴──────────────┘
# shape: (2, 4)
# ┌──────────────┬────────┬───────┬────────────┐
# │ career_level ┆ counts ┆ group ┆ row_filter │
# │ ---          ┆ ---    ┆ ---   ┆ ---        │
# │ str          ┆ f64    ┆ str   ┆ str        │
# ╞══════════════╪════════╪═══════╪════════════╡
# │ 5            ┆ 66.67  ┆ AFC   ┆ <2 years   │
# │ 3            ┆ 33.33  ┆ AFC   ┆ <2 years   │
# └──────────────┴────────┴───────┴────────────┘
# shape: (1, 4)
# ┌──────────────┬────────┬───────┬──────────────┐
# │ career_level ┆ counts ┆ group ┆ row_filter   │
# │ ---          ┆ ---    ┆ ---   ┆ ---          │
# │ str          ┆ f64    ┆ str   ┆ str          │
# ╞══════════════╪════════╪═══════╪══════════════╡
# │ 4            ┆ 100.0  ┆ AFC   ┆ 2 to 4 years │
# └──────────────┴────────┴───────┴──────────────┘

# %% [markdown]
# EOF
